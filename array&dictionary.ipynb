# %% [markdown]
# #### array

# %%
import array as ar
arr=ar.array('i',[1,2,3,4,4])

# %%
arr.append(0)
arr
# Out:
# array('i', [1, 2, 3, 4, 4, 0])

# %%
del arr[-1]
arr
# Out:
# array('i', [1, 2, 3, 4, 4])

# %%
arr.reverse()
arr
# Out:
# array('i', [4, 4, 3, 2, 1])

# %%
arr.count(4)
# Out:
# 2

# %%
arr.index(3)
# Out:
# 2

# %%
r=ar.array('i',[])
n=int(input())
for i in range(n):
    val=int(input())
    r.append(val)
print(r)
# Out:
#  5
#  2
#  3
#  4
#  1
#  4
# array('i', [2, 3, 4, 1, 4])

# %% [markdown]
# ### dictionary

# %% [raw]
# There are four collection data types in the Python programming language:
# ->List is a collection which is ordered and changeable. Allows duplicate members.\n
# ->Tuple is a collection which is ordered and unchangeable. Allows duplicate members.\n
# ->Set is a collection which is unordered, unchangeable, and unindexed. No duplicate members.\n
# ->Dictionary is a collection which is ordered and changeable. No duplicate members.

# %%
dic={'name':'maisa',
'versity':'nstu',
'dept':'cste'}
dic
# Out:
# {'name': 'maisa', 'versity': 'nstu', 'dept': 'cste'}

# %%
dic.keys()
# Out:
# dict_keys(['name', 'versity', 'dept'])

# %%
dic.values()
# Out:
# dict_values(['maisa', 'nstu', 'cste'])

# %%
dic1=dic.copy()
dic1
# Out:
# {'name': 'maisa', 'versity': 'nstu', 'dept': 'cste'}

# %%
dic['versity']='fau'

# %%
dic
# Out:
# {'name': 'maisa', 'versity': 'fau', 'dept': 'cste'}

# %%
dic.update({'dept':'ml'})
dic
# Out:
# {'name': 'maisa', 'versity': 'fau', 'dept': 'ml'}

# %%
dic.popitem()
# Out:
# ('dept', 'ml')

# %%
dic
# Out:
# {'name': 'maisa', 'versity': 'fau'}

# %%
for x in dic:
    print(dic[x])
# Out:
# maisa
# fau

# %%
for x in dic:
    print(x)
# Out:
# name
# versity

# %%
d1 = list(dic.keys())
d1
# Out:
# ['name', 'versity']

# %%
#user input
n=int(input())
d={}
for i in range(n):
    key=input()
    value=input()
    d[key]=value
print(d)
# Out:
#  3
#  maisa
#  habiba
#  dept
