# %% [markdown]
# #### tuple

# %% [markdown]
# A tuple in Python is similar to a List. The difference between the two is that we cannot change the elements of a tuple once it is assigned whereas we can change the elements of a list

# %%
tup=('ai',2,3,'ml',3,4,[2,3,4],True)
type(tup)
# Out:
# tuple

# %%
tup
# Out:
# ('ai', 2, 3, 'ml', 3, 4, [2, 3, 4], True)

# %%
tup[3]
# Out:
# 'ml'

# %%
tup[3:6]
# Out:
# ('ml', 3, 4)

# %%
l=['ai']
type(l)
# Out:
# list

# %%
t=('ai')
type(t)
# Out:
# str

# %%
tt=('ai',)
type(tt)
# Out:
# tuple

# %%
ll=list(tt)
type(ll)
# Out:
# list

# %%
tup1=1,2,3,'ai',3,4
tup1
# Out:
# (1, 2, 3, 'ai', 3, 4)

# %%
type(tup1)
# Out:
# tuple

# %%
# concatenation
tup1+tt
# Out:
# (1, 2, 3, 'ai', 3, 4, 'ai')

# %%
tupp=2,3,4,5
tp=tupp*2

# %%
#count
tp.count(3)
# Out:
# 2

# %%
#index
tp.index(3)
# Out:
# 1

# %%
# membership
'ai' in tup1
# Out:
# True

# %%
for i in tup1:
    print(i)
# Out:
# 1
# 2
# 3
# ai
# 3
# 4
