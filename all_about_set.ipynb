# %% [markdown]
# #### set

# %%
set1={1,2,3,(1,34,5),'ai'}#unchangeable & unindexed
set1
# Out:
# {(1, 34, 5), 1, 2, 3, 'ai'}

# %%
type(set1)
# Out:
# set

# %%
l=[]
type(l)
# Out:
# list

# %%
s={}
type(s)
# Out:
# dict

# %%
#for defining empty set
ss=set()
type(ss)
# Out:
# set

# %% [markdown]
# ### method

# %%
set1.add(100)

# %%
set1
# Out:
# {(1, 34, 5), 1, 100, 2, 3, 'ai'}

# %%
set1.update([10,20,30,40])
set1
# Out:
# {(1, 34, 5), 1, 10, 100, 2, 20, 3, 30, 40, 'ai'}

# %%
set1.remove('ai')
set1
# Out:
# {(1, 34, 5), 1, 10, 100, 2, 20, 3, 30, 40}

# %% [markdown]
# ### frozen set

# %%
sub={1,2,3,'ai','ds','dld','ml'}

# %%
fro=frozenset(sub)
fro
# Out:
# frozenset({1, 2, 3, 'ai', 'dld', 'ds', 'ml'})

# %%
li=[1,2,4,45]

# %%
s1=frozenset(li)
s1
# Out:
# frozenset({1, 2, 4, 45})

# %%
fro.union(s1)
# Out:
# frozenset({1, 2, 3, 4, 45, 'ai', 'dld', 'ds', 'ml'})

# %%
fro.intersection(s1)
# Out:
# frozenset({1, 2})

# %%
s1={1,2,3,4}
s2={1,2,'a','b'}

# %%
s3=frozenset(s2)
s3
# Out:
# frozenset({1, 2, 'a', 'b'})

# %% [markdown]
# ### function

# %%
s1.add('d')
s1
# Out:
# {1, 2, 3, 4, 'd'}

# %%
s2=s1
s2.remove('d')
s1
# Out:
# {1, 2, 3, 4}

# %%
s4=s1.copy()
s4.remove(4)
print(s1)
print(s4)
# Out:
# {1, 2, 3, 4}
# {1, 2, 3}

# %%
s1.difference(s3)
# Out:
# {3, 4}

# %%
s5={1,2,'a','b'}
s5.difference(s1)
# Out:
# {'a', 'b'}

# %%
s5.difference_update(s1)

# %%
s5
# Out:
# {'a', 'b'}

# %%
{'a'}.issubset(s5)
# Out:
# True

# %%
ss={7,8,1,2}
aa={4,5,1,2}
ss.symmetric_difference(aa)
# Out:
# {4, 5, 7, 8}
