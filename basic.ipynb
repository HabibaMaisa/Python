# %% [markdown]
# ### print() & input()

# %%
print('Hello world!' , 'Welcome to Python',sep=' & ',end=' | ')
# Out:
# Hello world! & Welcome to Python |

# %%
var='Hello world!'
print(var)
print('my sentence is '  +var)
# Out:
# Hello world!
# my sentence is Hello world!

# %%
id(var)
# Out:
# 1492627907696

# %%
import sys
sys.getsizeof(var)#memory koto byte lagce
# Out:
# 53

# %%
x,y,z=10,3,4
x
# Out:
# 10

# %% [markdown]
# ## string

# %%
data='data science'
type(data)
# Out:
# str

# %%
data=input()
# Out:
#  python

# %%
x=input()
y=input()
# Out:
#  10
#  20

# %%
x+y
# Out:
# '1020'

# %%
x=int(input('Enter num '))
y=int(input('Enter num '))
# Out:
# Enter num  20
# Enter num  30

# %%
x+y
# Out:
# 50

# %%
import sys
sys.getsizeof(x)
# Out:
# 28

# %%
s='60 days of python'
s.count('python')
# Out:
# 1

# %% [markdown]
# ## Python string methods

# %%
s
# Out:
# '60 days of python'

# %%
s.find('of')
# Out:
# 8

# %%
s.find('y',6,10)
s.find('y',6,14)
# Out:
# 12

# %%
s.index('y',6,14)
#s.index('y',6,10)
# Out:
# 12

# %%
s.lower()
# Out:
# '60 days of python'

# %%
s.upper()
# Out:
# '60 DAYS OF PYTHON'

# %%
s.casefold()#lower
# Out:
# '60 days of python'

# %%
z='maisa Is a Good Girl'
z.capitalize()
# Out:
# 'Maisa is a good girl'

# %%
z.swapcase()
# Out:
# 'MAISA iS A gOOD gIRL'

# %%
z.isupper()
# Out:
# False

# %%
z.isdigit()
# Out:
# False

# %%
z.encode()
# Out:
# b'maisa Is a Good Girl'

# %%
type(z.encode())
# Out:
# bytes

# %%
z.split()
# Out:
# ['maisa', 'Is', 'a', 'Good', 'Girl']

# %%
z.split()[0]
# Out:
# 'maisa'

# %%
z.center(50)
# Out:
# '               maisa Is a Good Girl               '

# %%
z.replace('Good','very good')
# Out:
# 'maisa Is a very good Girl'

# %%
a=20
b=3
c=a*b
print('I have ',c,' taka'
